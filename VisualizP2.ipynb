# %%
# Vemos la correlación entre la media del FIFA y los puntos actuales en La Liga

# %%
from IPython.display import Image
Image(filename='graph.png')

# %%
# Observamos que existe una correlación significativa, sobre todo teniendo en cuenta que tan solo se ha disputado
# un tercio de La Liga. En general, los equipos con mayor puntuación media en el FIFA, ya han obtenido más puntos
# que otros equipos con medias más bajas. No obstante existen excepciones, como la del Rayo Vallecano, que siendo
# el equipo con menos puntuación media, es el sexto en la clasificación actual.
